# %% [markdown]
# # **Checkpoint 2**

# %%
import pandas as pd

# %% [markdown]
# ## **Data Understanding**
# Dataset ini diperoleh dari [Kaggle - Amazon Monitor Sales](https://www.kaggle.com/datasets/durjoychandrapaul/amazon-products-sales-monitor-dataset)

# %%
df = pd.read_csv("/content/extracted_product_info_amazon.csv")

# %% [markdown]
# **1. Cek jumlah baris dan kolom**

# %%
print(f"Dataset memiliki {df.shape[0]} baris dan {df.shape[1]} kolom.\n")
# Out:
# Dataset memiliki 947 baris dan 7 kolom.

# %% [markdown]
# **2. Cek tipe data setiap kolom**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 947 entries, 0 to 946
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         947 non-null    object
#  1   Brand         947 non-null    object
#  2   Screen Size   947 non-null    object
#  3   Resolution    947 non-null    object
#  4   Aspect Ratio  947 non-null    object
#  5   Rating        947 non-null    object
#  6   Price         947 non-null    object
# dtypes: object(7)
# memory usage: 51.9+ KB

# %% [markdown]
# **3. Tampilkan 5 data pertama dan terakhir untuk melihat isi dataset (jika baris banyak)**

# %%
df
# Out:
#                                                  Title      Brand  \
# 0    acer SB240Y G0bi 23.8" IPS Full HD Ultra-Slim ...       acer
# 1    acer Nitro 31.5" FHD 1920 x 1080 1500R Curved ...       acer
# 2    Acer SB272 EBI 27" Full HD (1920 x 1080) IPS Z...       acer
# 3    Sceptre 30-inch Curved Gaming Monitor 21:9 256...    Sceptre
# 4    SAMSUNG 32" UJ59 Series 4K UHD (3840x2160) Com...    SAMSUNG
# ..                                                 ...        ...
# 942  acer SB270 G0bi 27" IPS Full HD (1920 x 1080) ...       acer
# 943  ASUS 31.5” 1080P Monitor (VA329HE) - Full HD, ...       ASUS
# 944  Acer Predator XB273K V3bmiiprx 27" UHD 3840x21...       acer
# 945  Acer Nitro 34" UWQHD 3440 x 1440 1500R Curved ...       acer
# 946             ViewSonic N1630w 16-Inch 720p LCD HDTV  ViewSonic
#
#      Screen Size            Resolution Aspect Ratio Rating   Price
# 0    23.8 Inches             FHD 1080p         16:9    4.4   94.99
# ...

# %% [markdown]
# **4. statistik deskriptif**

# %%
df.describe()
# Out:
#                                                     Title Brand Screen Size  \
# count                                                 947   947         947
# unique                                                296    62          57
# top     ASUS 31.5” 1080P Monitor (VA329HE) - Full HD, ...  acer   27 Inches
# freq                                                   84   532         260
#
#        Resolution Aspect Ratio Rating   Price
# count         947          947    947     947
# unique         41           16     25     166
# top     FHD 1080p         16:9    4.6  199.99
# freq          566          833    368     122

# %% [markdown]
# **5. analisis korelasi**

# %%
corr_matrix = df[["Rating", "Price"]].corr()

# %%
print("\nMatriks Korelasi:")
print(corr_matrix)
# Out:
# Matriks Korelasi:
#           Rating     Price
# Rating  1.000000 -0.315986
# Price  -0.315986  1.000000

# %% [markdown]
# ## **Data Preparation**
# Dataset ini diperoleh dari [Kaggle - Amazon Monitor Sales](https://www.kaggle.com/datasets/durjoychandrapaul/amazon-products-sales-monitor-dataset)

# %% [markdown]
# ## A. Pengecekan terhadap Data

# %% [markdown]
# **1. nilai yang hilang (Missing Values)**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Title           0.000000
# Brand           0.000000
# Screen Size     0.000000
# Resolution      0.000000
# Aspect Ratio    0.000000
# Rating          3.695882
# Price           0.844773
# dtype: float64

# %% [markdown]
# *   Rating

# %%
df[df['Rating'].isnull()]
# Out:
#                                                  Title                Brand  \
# 357  MSI PRO MP273U, IPS 3840 x 2160 (UHD) Computer...                  MSI
# 363  LG 32” 32SM5J-B Full HD Standard Signage Displ...                   LG
# 375  KTC 48 Inch 4K OLED Gaming Monitor, 0.1ms GTG ...                  KTC
# 385  HP Series 5 524sa Monitor with Speakers 94C36A...                   HP
# 411  4K Portable Monitor 16 inch 3840x2400 UHD USB ...               LESOWN
# 412  Samsung QM43C 43-inch Commercial 4k Uhd Displa...              SAMSUNG
# 425  LG 27BN85UN-B 27” IPS UHD 4K Monitor (3840x216...                   LG
# 455  Z-Edge Curved Gaming Monitor Bundle [27-inch 2...             Z Z-EDGE
# 464  Lenovo ThinkVision T22i-30 21.5 Full HD WLED L...               Lenovo
# 465       LG Ultragear 27" 1440p 165 Hz Gaming Monitor                   LG
# 503     NEC X464UNS 46" Full HD Commercial LED Monitor                  NEC
# ...

# %% [markdown]
# *   Price

# %%
df[df['Price'].isnull()]
# Out:
#                                                  Title     Brand  Screen Size  \
# 39   LG ‎32GS95UE 32-inch Ultragear OLED Gaming Mon...        LG  31.5 Inches
# 97   Dell UltraSharp U3223QE 31.5" 4K UHD WLED LCD ...      Dell  31.5 Inches
# 124  SAMSUNG 32" Odyssey Neo G8 4K UHD 240Hz 1ms G-...   SAMSUNG    32 Inches
# 313  BenQ SW272U 27-Inch 4K 90W USB-C Photographer ...      BenQ    27 Inches
# 426  86" Touchscreen Monitor Smart Board, 4K Intera...   TouchWo    86 Inches
# 444  LG 27” 27BP85UN-W IPS 4K UHD Computer Monitor ...        LG    27 Inches
# 448  Tilta Nucleus-M Brushless Wireless Follow Focu...     Tilta   4.7 Inches
# 640  LILLLIPUT Q23-8K -23.8" 8K 12G-SDI Production ...  LILLIPUT  23.8 Inches
#
#            Resolution Aspect Ratio  Rating  Price
# 39       4K UHD 2160p         16:9     4.2    NaN
# 97       4K UHD 2160p         16:9     4.4    NaN
# 124      4K UHD 2160p         16:9     3.9    NaN
# 313      4K UHD 2160p         16:9     4.4    NaN
# ...

# %% [markdown]
# **2. Duplicated Values**

# %%
df[df.duplicated()]
# Out:
#                                                  Title Brand  Screen Size  \
# 29   Acer CB272 Ebmiprx 27" FHD 1920 x 1080 Zero Fr...  acer    27 Inches
# 32   Acer KB252Q E0bi 24.5" IPS Full HD (1920 x 108...  acer  24.5 Inches
# 33   acer SB240Y G0bi 23.8" IPS Full HD Ultra-Slim ...  acer  23.8 Inches
# 34   Acer Nitro 34" UWQHD 3440 x 1440 1500R Curved ...  acer    34 Inches
# 47   Acer SB272 EBI 27" Full HD (1920 x 1080) IPS Z...  acer    27 Inches
# ..                                                 ...   ...          ...
# 941  Acer Nitro 31.5" WQHD 2560 x 1440 1500R Curved...  acer  31.5 Inches
# 942  acer SB270 G0bi 27" IPS Full HD (1920 x 1080) ...  acer    27 Inches
# 943  ASUS 31.5” 1080P Monitor (VA329HE) - Full HD, ...  ASUS    32 Inches
# 944  Acer Predator XB273K V3bmiiprx 27" UHD 3840x21...  acer    27 Inches
# 945  Acer Nitro 34" UWQHD 3440 x 1440 1500R Curved ...  acer    34 Inches
#
#                Resolution Aspect Ratio  Rating   Price
# ...

# %% [markdown]
# **3. Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom   Persentase Outliers
# Rating             6.969377
# Price              2.534319

# %%
df
# Out:
#                                                  Title      Brand  \
# 0    acer SB240Y G0bi 23.8" IPS Full HD Ultra-Slim ...       acer
# 1    acer Nitro 31.5" FHD 1920 x 1080 1500R Curved ...       acer
# 2    Acer SB272 EBI 27" Full HD (1920 x 1080) IPS Z...       acer
# 3    Sceptre 30-inch Curved Gaming Monitor 21:9 256...    Sceptre
# 4    SAMSUNG 32" UJ59 Series 4K UHD (3840x2160) Com...    SAMSUNG
# ..                                                 ...        ...
# 942  acer SB270 G0bi 27" IPS Full HD (1920 x 1080) ...       acer
# 943  ASUS 31.5” 1080P Monitor (VA329HE) - Full HD, ...       ASUS
# 944  Acer Predator XB273K V3bmiiprx 27" UHD 3840x21...       acer
# 945  Acer Nitro 34" UWQHD 3440 x 1440 1500R Curved ...       acer
# 946             ViewSonic N1630w 16-Inch 720p LCD HDTV  ViewSonic
#
#      Screen Size            Resolution Aspect Ratio  Rating   Price
# 0    23.8 Inches             FHD 1080p         16:9     4.4   94.99
# ...

# %% [markdown]
# **4. Incosistent Value**

# %% [markdown]
# Menurut Saya, dataset yang saya teliti tidak ada nilai yang tidak konsisten

# %% [markdown]
# ## B. Penanganan terhadap Data

# %% [markdown]
# **1. nilai yang hilang (Missing Values)**

# %% [markdown]
# *   Rating (Imputasi)

# %%
df['Rating'].dropna().describe()
# Out:
# count    912.000000
# mean       4.450000
# std        0.287233
# min        1.000000
# 25%        4.400000
# 50%        4.500000
# 75%        4.600000
# max        5.000000
# Name: Rating, dtype: float64

# %%
df['Rating'] = df['Rating'].fillna(df['Rating'].dropna().mean())

# %% [markdown]
# *   Price (Imputasi)

# %%
df['Price'].dropna().describe()
# Out:
# count    939.000000
# mean     202.810990
# std      128.672174
# min        7.340000
# 25%       99.990000
# 50%      157.990000
# 75%      255.490000
# max      949.990000
# Name: Price, dtype: float64

# %%
df['Price'] = df['Price'].fillna(df['Price'].dropna().mean())

# %% [markdown]
# **2. Duplicated Values (Dihapus semua duplikasi)**

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                                                  Title                Brand  \
# 0    acer SB240Y G0bi 23.8" IPS Full HD Ultra-Slim ...                 acer
# 1    acer Nitro 31.5" FHD 1920 x 1080 1500R Curved ...                 acer
# 2    Acer SB272 EBI 27" Full HD (1920 x 1080) IPS Z...                 acer
# 3    Sceptre 30-inch Curved Gaming Monitor 21:9 256...              Sceptre
# 4    SAMSUNG 32" UJ59 Series 4K UHD (3840x2160) Com...              SAMSUNG
# ..                                                 ...                  ...
# 926                     AXIS TC1603 Tile Bridge, 2 pcs  Axis Communications
# 930  NEC MultiSync UN552V 55" 16:9 Full HD S-IPS Ul...                  NEC
# 931  Elo E017030 Desktop Touchmonitors 1717L iTouch...                  Elo
# 936  Dell S2240L 21.5-Inch Virtually Borderless/Ult...                 Dell
# 946             ViewSonic N1630w 16-Inch 720p LCD HDTV            ViewSonic
#
# ...

# %% [markdown]
# **3. Outliers (Melakukan imputasi)**

# %%
columns_to_impute = ["Rating", "Price"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Melakukan Pengecekan Ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom   Persentase Outliers
# Rating                  0.0
# Price                   0.0

# %%
df
# Out:
#                                                  Title                Brand  \
# 0    acer SB240Y G0bi 23.8" IPS Full HD Ultra-Slim ...                 acer
# 1    acer Nitro 31.5" FHD 1920 x 1080 1500R Curved ...                 acer
# 2    Acer SB272 EBI 27" Full HD (1920 x 1080) IPS Z...                 acer
# 3    Sceptre 30-inch Curved Gaming Monitor 21:9 256...              Sceptre
# 4    SAMSUNG 32" UJ59 Series 4K UHD (3840x2160) Com...              SAMSUNG
# ..                                                 ...                  ...
# 926                     AXIS TC1603 Tile Bridge, 2 pcs  Axis Communications
# 930  NEC MultiSync UN552V 55" 16:9 Full HD S-IPS Ul...                  NEC
# 931  Elo E017030 Desktop Touchmonitors 1717L iTouch...                  Elo
# 936  Dell S2240L 21.5-Inch Virtually Borderless/Ult...                 Dell
# 946             ViewSonic N1630w 16-Inch 720p LCD HDTV            ViewSonic
#
# ...

# %% [markdown]
# **4. Incosistent Value**

# %% [markdown]
# Menurut Saya, dataset yang saya teliti tidak ada nilai yang tidak konsisten

# %% [markdown]
# ##  konstruksi data (Construct Data) (penambahan kolom)

# %% [markdown]
# **Penambahan Kolom: Kategori harga**

# %%
df_cleaned = df.copy()

# %%
df_cleaned["Price"] = pd.to_numeric(df_cleaned["Price"], errors="coerce")

# %%
def kategori_harga(Price):
    if Price < 150:
        return "Murah"
    elif 150 <= Price <= 400:
        return "Menengah"
    else:
        return "Mahal"

# %%
df_cleaned["kategori_Harga"] = df_cleaned["Price"].apply(kategori_harga)

# %%
print(df_cleaned[["Price", "kategori_Harga"]])
# Out:
#       Price kategori_Harga
# 0     94.99          Murah
# 1    259.99       Menengah
# 2     99.99          Murah
# 3    199.97       Menengah
# 4    279.99       Menengah
# ..      ...            ...
# 942  147.35          Murah
# 943  157.99       Menengah
# 944  399.99       Menengah
# 945  299.99       Menengah
# 946   59.97          Murah
#
# [947 rows x 2 columns]

# %% [markdown]
# **Penambahan Kolom: Kategori harga (dari rating/penilaian 1 sampai 5 menjadi 1 sampai 100)**

# %%
if "Rating" in df_cleaned.columns:
    df_cleaned["Rating_yang_disesuaikan"] = df_cleaned["Rating"] * 20

# %%
print(df_cleaned[["Rating", "Rating_yang_disesuaikan"]])
# Out:
#      Rating  Rating_yang_disesuaikan
# 0       4.4                     88.0
# 1       4.6                     92.0
# 2       4.5                     90.0
# 3       4.5                     90.0
# 4       4.3                     86.0
# ..      ...                      ...
# 942     4.5                     90.0
# 943     4.5                     90.0
# 944     4.4                     88.0
# 945     4.6                     92.0
# 946     3.2                     64.0
#
# [947 rows x 2 columns]

# %% [markdown]
# ##  reduksi data (Data Reduction)

# %% [markdown]
# **menghapus kolom "Title"**
# Mengapa dihapus?
# *   "Title" berisi nama produk dalam bentuk teks panjang, yang tidak terlalu berguna untuk analisis numerik (dan data seperti brand dan lainnya sudah ada kolom sendiri)
# *   Kolom lainnya masih berguna untuk analisis pola pembelian, harga, dan kualitas monitor

# %%
df = df.drop('Title', axis=1)

# %%
df
# Out:
#          Brand  Screen Size            Resolution Aspect Ratio  Rating   Price
# 0         acer  23.8 Inches             FHD 1080p         16:9     4.4   94.99
# 1         acer  31.5 Inches             FHD 1080p         16:9     4.6  259.99
# 2         acer    27 Inches             FHD 1080p         16:9     4.5   99.99
# 3      Sceptre    30 Inches  FHD 1080p Ultra Wide         21:9     4.5  199.97
# 4      SAMSUNG  31.5 Inches          4K UHD 2160p         16:9     4.3  279.99
# ..         ...          ...                   ...          ...     ...     ...
# 942       acer    27 Inches             FHD 1080p         16:9     4.5  147.35
# 943       ASUS    32 Inches             FHD 1080p         16:9     4.5  157.99
# 944       acer    27 Inches          4K UHD 2160p         16:9     4.4  399.99
# 945       acer    34 Inches  QHD Ultra Wide 1440p         21:9     4.6  299.99
# 946  ViewSonic    16 Inches                    HD         16:9     3.2   59.97
#
# [947 rows x 6 columns]
